# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('linear_regression_dataset.csv')
dataset.head()

X = dataset.iloc[:, :-1].values
print(X[1])

y = dataset.iloc[:,1].values 
print(y[1])
# Out:
# [9.8]
# 24.85

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=1/3)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
x = float(input())
y = regressor.predict([[x]])
print(y)
# Out:
# 9.9
# [25.92310085]

# %%
plt.scatter(x, y, color='red')
plt.scatter(X_train,y_train,color="green")
plt.xlabal("cgpa")
plt.ylabal("package")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 3
#       1 plt.scatter(x, y, color='red')
#       2 plt.scatter(X_train,y_train,color="green")
# ----> 3 plt.xlabal("cgpa")
#       4 plt.ylabal("package")
#       5 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlabal'
